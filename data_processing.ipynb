# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  adcode    name  新增疑似  累计疑似  新增确诊  累计确诊  新增死亡  累计死亡  adcode.1  \
# 0           0  110000     北京市     0     0     0     0     0     0    110000
# 1           1  120000     天津市     0     0     0     0     0     0    120000
# 2           2  130000     河北省     0     0     0     0     0     0    130000
# 3           3  140000     山西省     0     0     0     0     0     0    140000
# 4           4  150000  内蒙古自治区     0     0     0     0     0     0    150000
#
#    ... 累计死亡.47  adcode.48  name.48  OBJECTID1.17  新增疑似.48  累计疑似.48  新增确诊.48  \
# 0  ...       8     110000      北京市             1       10       34        1
# 1  ...       3     120000      天津市             2       11       33        0
# 2  ...       6     130000      河北省             3        0        0        0
# 3  ...       0     140000      山西省             4        0        0        0
# 4  ...       1     150000   内蒙古自治区             5        0        1        0
#
#    累计确诊.48 新增死亡.48  累计死亡.48
# ...

# %%
col_n = ['新增疑似.{}'.format(i) for i in range(1,49)] 
a = pd.DataFrame(df,columns = col_n)
a.to_csv('new_suspected.csv',encoding='utf-8-sig')

# %%
col_n = ['累计疑似.{}'.format(i) for i in range(1,49)]
b = pd.DataFrame(df,columns = col_n)
b.to_csv('cum_suspected.csv',encoding='utf-8-sig')

# %%
col_n = ['新增确诊.{}'.format(i) for i in range(1,49)]
b = pd.DataFrame(df,columns = col_n)
b.to_csv('new_confirmed.csv',encoding='utf-8-sig')

# %%
col_n = ['累计确诊.{}'.format(i) for i in range(1,49)]
b = pd.DataFrame(df,columns = col_n)
b.to_csv('cum_confirmed.csv',encoding='utf-8-sig')

# %%
col_n = ['累计死亡.{}'.format(i) for i in range(1,49)]
b = pd.DataFrame(df,columns = col_n)
b.to_csv('cum_dead.csv',encoding='utf-8-sig')

# %%
col_n = ['新增死亡.{}'.format(i) for i in range(1,49)]
b = pd.DataFrame(df,columns = col_n)
b.to_csv('new_dead.csv',encoding='utf-8-sig')

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'adcode', 'name', '新增疑似', '累计疑似', '新增确诊', '累计确诊',
#        '新增死亡', '累计死亡', 'adcode.1', 'name.1', '新增疑似.1', '累计疑似.1', '新增确诊.1',
#        '累计确诊.1', '新增死亡.1', '累计死亡.1', 'adcode.2', 'name.2', '新增疑似.2',
#        '累计疑似.2', '新增确诊.2', '累计确诊.2', '新增死亡.2', '累计死亡.2', 'adcode.3',
#        'name.3', '新增疑似.3', '累计疑似.3', '新增确诊.3', '累计确诊.3', '新增死亡.3',
#        '累计死亡.3', 'adcode.4', 'name.4', '新增疑似.4', '累计疑似.4', '新增确诊.4',
#        '累计确诊.4', '新增死亡.4', '累计死亡.4', 'adcode.5', 'name.5', '新增疑似.5',
#        '累计疑似.5', '新增确诊.5', '累计确诊.5', '新增死亡.5', '累计死亡.5', 'adcode.6',
#        'name.6', '新增疑似.6', '累计疑似.6', '新增确诊.6', '累计确诊.6', '新增死亡.6',
#        '累计死亡.6', 'adcode.7', 'name.7', '新增疑似.7', '累计疑似.7', '新增确诊.7',
#        '累计确诊.7', '新增死亡.7', '累计死亡.7', 'adcode.8', 'name.8', '新增疑似.8',
#        '累计疑似.8', '新增确诊.8', '累计确诊.8', '新增死亡.8', '累计死亡.8', 'adcode.9',
#        'name.9', '新增疑似.9', '累计疑似.9', '新增确诊.9', '累计确诊.9', '新增死亡.9',
# ...
